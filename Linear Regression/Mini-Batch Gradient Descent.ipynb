# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score 
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
 X,y = load_diabetes(return_X_y=True)

# %%
X.shape , y.shape
# Out:
# ((442, 10), (442,))

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
reg = LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(reg.coef_)
print(reg.intercept_)
# Out:
# [  -9.15865318 -205.45432163  516.69374454  340.61999905 -895.5520019
#   561.22067904  153.89310954  126.73139688  861.12700152   52.42112238]
# 151.88331005254167

# %%
y_pred = reg.predict(X_test)
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968

# %%
class SGDRegressor:
    
    def __init__(self, learning_rate=0.01, epochs=100):
        # Model parameters
        self.coef_ = None        # coefficients (w1, w2, ..., wn)
        self.intercept_ = None   # intercept (b)
        self.lr = learning_rate  # learning rate (α)
        self.epochs = epochs     # number of passes over dataset
        
    def fit(self, X_train, y_train):
        # Initialize intercept and coefficients
        self.intercept_ = 0
        self.coef_ = np.ones(X_train.shape[1])  # start with wj = 1
        
        # Run for the given number of epochs
        for i in range(self.epochs):
            for j in range(X_train.shape[0]):
                
                # Randomly pick one sample (stochastic)
                idx = np.random.randint(0, X_train.shape[0])
                
                # Prediction for that one sample: ŷ = xi·w + b
                y_hat = np.dot(X_train[idx], self.coef_) + self.intercept_
                
                # -------- Gradient for Intercept (bias term) --------
                # ∂L/∂b = -2 * (y - ŷ)
                intercept_der = -2 * (y_train[idx] - y_hat)
                
                # Update rule: b := b - α * ∂L/∂b
                self.intercept_ = self.intercept_ - (self.lr * intercept_der)

                # -------- Gradient for Coefficients (weights) --------
                # ∂L/∂w = -2 * xi * (y - ŷ)
                coef_der = -2 * np.dot((y_train[idx] - y_hat), X_train[idx])
                
                # Update rule: w := w - α * ∂L/∂w
                self.coef_ = self.coef_ - (self.lr * coef_der)
        
        # Print learned parameters
        print("Final intercept (b):", self.intercept_)
        print("Final coefficients (w):", self.coef_)
    
    def predict(self, X_test):
        # Prediction formula: ŷ = X·w + b
        return np.dot(X_test, self.coef_) + self.intercept_

# %%
gdr = SGDRegressor(epochs=1000,learning_rate=0.5)

# %%
gdr.fit(X_train,y_train)
# Out:
# Final intercept (b): 106.79924790763226
# Final coefficients (w): [  20.97626675 -262.97745347  523.70609844  236.48780385 -836.22100443
#   569.87717401  249.69097146  224.4318363   873.39199204  -16.30346273]

# %%
r2_score(y_test,y_pred)
# Out:
# 0.4399338661568968
