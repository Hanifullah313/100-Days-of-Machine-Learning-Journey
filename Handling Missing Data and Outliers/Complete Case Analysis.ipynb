# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("data_science_job.csv")
df.head()
# Out:
#    enrollee_id      city  city_development_index gender  \
# 0         8949  city_103                   0.920   Male
# 1        29725   city_40                   0.776   Male
# 2        11561   city_21                   0.624    NaN
# 3        33241  city_115                   0.789    NaN
# 4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0  Has relevent experience       no_enrollment        Graduate
# 1   No relevent experience       no_enrollment        Graduate
# 2   No relevent experience    Full time course        Graduate
# 3   No relevent experience                 NaN        Graduate
# 4  Has relevent experience       no_enrollment         Masters
#
#   major_discipline  experience company_size    company_type  training_hours  \
# 0             STEM        20.0          NaN             NaN            36.0
# 1             STEM        15.0        50-99         Pvt Ltd            47.0
# 2             STEM         5.0          NaN             NaN            83.0
# 3  Business Degree         0.0          NaN         Pvt Ltd            52.0
# 4             STEM        20.0        50-99  Funded Startup             8.0
#
#    target
# 0     1.0
# 1     0.0
# 2     0.0
# 3     1.0
# 4     0.0

# %%
df.isnull().mean()*100
# Out:
# enrollee_id                0.000000
# city                       0.000000
# city_development_index     2.500261
# gender                    23.530640
# relevent_experience        0.000000
# enrolled_university        2.014824
# education_level            2.401086
# major_discipline          14.683161
# experience                 0.339284
# company_size              30.994885
# company_type              32.049274
# training_hours             3.998330
# target                     0.000000
# dtype: float64

# %%
cols = [var for var in df.columns if 0 < df[var].isnull().mean() < 0.5]
df[cols].sample(5)
# Out:
#        city_development_index gender enrolled_university education_level  \
# 5671                    0.624   Male    Full time course        Graduate
# 16067                   0.624   Male    Full time course        Graduate
# 6081                    0.920   Male       no_enrollment        Graduate
# 9400                    0.920   Male       no_enrollment        Graduate
# 6974                    0.920   Male       no_enrollment        Graduate
#
#       major_discipline  experience company_size    company_type  \
# 5671              STEM         5.0        50-99             NaN
# 16067             STEM         NaN    1000-4999         Pvt Ltd
# 6081              STEM        12.0        10/49         Pvt Ltd
# 9400              Arts        20.0          NaN             NaN
# 6974              STEM         9.0      100-500  Funded Startup
#
#        training_hours
# 5671             47.0
# 16067            18.0
# 6081             25.0
# 9400            103.0
# 6974            107.0

# %%
len(df[cols].dropna())/len(df)
# Out:
# 0.44023384486898426

# %%
new_df = df.dropna()
new_df.shape , df.shape
# Out:
# ((8434, 13), (19158, 13))

# %%
df.hist( figsize = (12,22))
new_df.hist( figsize = (12,22))
plt.show()
